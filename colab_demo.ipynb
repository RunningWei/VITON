# %% [markdown]
# <a href="https://colab.research.google.com/github/RunningWei/VITON/blob/master/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # 准备

# %%
# %cd /content/drive/My Drive/VITON/VITON
# Out:
# /content/drive/My Drive/VITON/VITON

# %%
# !git clone https://github.com/xthan/VITON.git
# Out:
# Cloning into 'VITON'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 150.71 KiB | 1.08 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
# %cd VITON
# Out:
# /content/drive/My Drive/VITON/VITON

# %% [markdown]
# Put pretrained model under model/ folder

# %%
# !cp -r /content/drive/My\ Drive/VITON/pre_trained_model_in_VITON/model/* model/

# %% [markdown]
# avoid discrepancy

# %%
# !pip install scipy==1.1.0
# Out:
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 40.8MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.16.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.3.0
#     Uninstalling scipy-1.3.0:
#       Successfully uninstalled scipy-1.3.0
# Successfully installed scipy-1.1.0

# %% [markdown]
# ## install octave

# %%
# !apt install octave
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   aglfn epstool fonts-droid-fallback fonts-noto-mono ghostscript gnuplot-data
#   gnuplot-qt gsfonts imagemagick-6-common info install-info libamd2
#   libauthen-sasl-perl libcamd2 libccolamd2 libcholmod3 libcolamd2
#   libcupsfilters1 libcupsimage2 libcxsparse3 libdata-dump-perl libemf1
#   libencode-locale-perl libfftw3-single3 libfile-listing-perl libfltk-gl1.3
#   libfltk1.3 libfont-afm-perl libgail-common libgail18 libglpk40
#   libgraphicsmagick++-q16-12 libgraphicsmagick-q16-3 libgs9 libgs9-common
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libhtml-form-perl
#   libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl
#   libhtml-tree-perl libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libijs-0.35 libio-html-perl
#   libio-socket-ssl-perl libjbig2dec0 liblqr-1-0 liblua5.3-0
#   liblwp-mediatypes-perl liblwp-protocol-https-perl libmagick++-6.q16-7
#   libmagickcore-6.q16-3 libmagickwand-6.q16-3 libmailtools-perl libmetis5
#   libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl libnotify4
#   liboctave4 libosmesa6 libplot2c2 libportaudio2 libpstoedit0c2a libqrupdate1
#   libqscintilla2-qt5-13 libqscintilla2-qt5-l10n libqt5opengl5 libqt5svg5
#   libsuitesparseconfig5 libtext-unidecode-perl libtimedate-perl
#   libtry-tiny-perl libumfpack5 liburi-perl libwmf0.2-7 libwww-perl
#   libwww-robotrules-perl libwxbase3.0-0v5 libwxgtk3.0-0v5 libxml-libxml-perl
#   libxml-namespacesupport-perl libxml-parser-perl libxml-sax-base-perl
#   libxml-sax-expat-perl libxml-sax-perl libzip4 netbase notification-daemon
#   octave-common octave-doc perl-openssl-defaults poppler-data pstoedit
#   tex-common texinfo
# Suggested packages:
#   fonts-noto ghostscript-x gnuplot-doc texinfo-doc-nonfree libdigest-hmac-perl
#   libgssapi-perl libfftw3-bin libfftw3-dev libiodbc2-dev
#   default-libmysqlclient-dev graphicsmagick-dbg gvfs libcrypt-ssleay-perl
#   libmagickcore-6.q16-3-extra libqscintilla2-doc libwmf0.2-7-gtk
#   libauthen-ntlm-perl liboctave-dev www-browser | pdf-viewer poppler-utils
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum xfig
#   | ivtools-bin | tgif | transfig debhelper texlive-base texlive-latex-base
#   texlive-generic-recommended texlive-fonts-recommended
# The following NEW packages will be installed:
#   aglfn epstool fonts-droid-fallback fonts-noto-mono ghostscript gnuplot-data
#   gnuplot-qt gsfonts imagemagick-6-common info install-info libamd2
#   libauthen-sasl-perl libcamd2 libccolamd2 libcholmod3 libcolamd2
#   libcupsfilters1 libcupsimage2 libcxsparse3 libdata-dump-perl libemf1
#   libencode-locale-perl libfftw3-single3 libfile-listing-perl libfltk-gl1.3
#   libfltk1.3 libfont-afm-perl libgail-common libgail18 libglpk40
#   libgraphicsmagick++-q16-12 libgraphicsmagick-q16-3 libgs9 libgs9-common
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libhtml-form-perl
#   libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl
#   libhtml-tree-perl libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libijs-0.35 libio-html-perl
#   libio-socket-ssl-perl libjbig2dec0 liblqr-1-0 liblua5.3-0
#   liblwp-mediatypes-perl liblwp-protocol-https-perl libmagick++-6.q16-7
#   libmagickcore-6.q16-3 libmagickwand-6.q16-3 libmailtools-perl libmetis5
#   libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl libnotify4
#   liboctave4 libosmesa6 libplot2c2 libportaudio2 libpstoedit0c2a libqrupdate1
#   libqscintilla2-qt5-13 libqscintilla2-qt5-l10n libqt5opengl5 libqt5svg5
#   libsuitesparseconfig5 libtext-unidecode-perl libtimedate-perl
#   libtry-tiny-perl libumfpack5 liburi-perl libwmf0.2-7 libwww-perl
#   libwww-robotrules-perl libwxbase3.0-0v5 libwxgtk3.0-0v5 libxml-libxml-perl
#   libxml-namespacesupport-perl libxml-parser-perl libxml-sax-base-perl
#   libxml-sax-expat-perl libxml-sax-perl libzip4 netbase notification-daemon
#   octave octave-common octave-doc perl-openssl-defaults poppler-data pstoedit
#   tex-common texinfo
# 0 upgraded, 103 newly installed, 0 to remove and 4 not upgraded.
# Need to get 53.4 MB of archives.
# After this operation, 208 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 install-info amd64 6.5.0.dfsg.1-2 [55.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6-common all 8:6.9.7.4+dfsg-16ubuntu6.7 [60.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.7 [1,615 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.7 [293 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libqt5svg5 amd64 5.9.5-0ubuntu1 [128 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 tex-common all 6.09 [33.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 netbase all 5.4 [12.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 info amd64 6.5.0.dfsg.1-2 [104 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.6 [18.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.9 [5,092 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.9 [2,264 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.9 [51.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/universe amd64 epstool amd64 3.08+repack-7 [108 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 aglfn all 1.7-3 [29.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gnuplot-data all 5.2.2+dfsg1-2ubuntu1 [56.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblua5.3-0 amd64 5.3.3-1ubuntu0.18.04.1 [115 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwxbase3.0-0v5 amd64 3.0.4+dfsg-3 [954 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnotify4 amd64 0.7.7-3 [17.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwxgtk3.0-0v5 amd64 3.0.4+dfsg-3 [4,182 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gnuplot-qt amd64 5.2.2+dfsg1-2ubuntu1 [1,013 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsuitesparseconfig5 amd64 1:5.1.2-2 [9,044 B]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libamd2 amd64 1:5.1.2-2 [19.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcamd2 amd64 1:5.1.2-2 [20.9 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libccolamd2 amd64 1:5.1.2-2 [21.7 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcolamd2 amd64 1:5.1.2-2 [16.2 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmetis5 amd64 5.1.0.dfsg-5 [169 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcholmod3 amd64 1:5.1.2-2 [300 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcxsparse3 amd64 1:5.1.2-2 [63.9 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdata-dump-perl all 1.23-1 [27.0 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libemf1 amd64 1.0.9+git.10.3231442-1 [54.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-single3 amd64 3.3.7-1 [764 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-date-perl all 6.02-1 [10.4 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-listing-perl all 6.04-1 [9,774 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfltk1.3 amd64 1.3.4-6 [523 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfltk-gl1.3 amd64 1.3.4-6 [37.7 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfont-afm-perl all 1.20-2 [13.2 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglpk40 amd64 4.65-1 [378 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwmf0.2-7 amd64 0.2.8.4-12 [150 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgraphicsmagick-q16-3 amd64 1.3.28-2 [1,112 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgraphicsmagick++-q16-12 amd64 1.3.28-2 [102 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tagset-perl all 3.20-3 [12.1 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/main amd64 liburi-perl all 1.73-1 [77.2 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-parser-perl amd64 3.72-3build1 [85.9 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-mediatypes-perl all 6.02-1 [21.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-message-perl all 6.14-1 [72.1 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-form-perl all 6.03-1 [23.5 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tree-perl all 5.07-1 [200 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-format-perl all 2.12-1 [41.3 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-cookies-perl all 6.04-1 [17.2 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-daemon-perl all 6.01-1 [17.0 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-negotiate-perl all 6.00-2 [13.4 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/main amd64 perl-openssl-defaults amd64 3build1 [7,012 B]
# Get:69 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnet-ssleay-perl amd64 1.84-1ubuntu0.1 [284 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libio-socket-ssl-perl all 2.060-3~ubuntu18.04.1 [173 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnet-http-perl all 6.17-1 [22.7 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtry-tiny-perl all 0.30-1 [20.5 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwww-robotrules-perl all 6.01-1 [14.1 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwww-perl all 6.31-1ubuntu0.1 [137 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-protocol-https-perl all 6.07-2 [8,284 B]
# Get:76 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagick++-6.q16-7 amd64 8:6.9.7.4+dfsg-16ubuntu6.7 [139 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnet-smtp-ssl-perl all 1.04-1 [5,948 B]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmailtools-perl all 2.18-1 [74.0 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqrupdate1 amd64 1.1.2-2build1 [36.5 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/main amd64 libumfpack5 amd64 1:5.1.2-2 [229 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liboctave4 amd64 4.2.2-1ubuntu1 [6,736 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libplot2c2 amd64 2.6-9 [502 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportaudio2 amd64 19.6.0-1 [64.6 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzip4 amd64 1.1.2-1.1 [37.8 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpstoedit0c2a amd64 3.70-5 [349 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqscintilla2-qt5-l10n all 2.10.2+dfsg-4 [39.7 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqscintilla2-qt5-13 amd64 2.10.2+dfsg-4 [1,030 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libqt5opengl5 amd64 5.9.5+dfsg-0ubuntu2.1 [132 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtext-unidecode-perl all 1.30-1 [99.0 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxml-namespacesupport-perl all 1.12-1 [13.2 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxml-sax-base-perl all 1.09-1 [18.8 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxml-sax-perl all 0.99+dfsg-2ubuntu1 [64.6 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxml-libxml-perl amd64 2.0128+dfsg-5 [316 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxml-parser-perl amd64 2.44-2build3 [199 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxml-sax-expat-perl all 0.40-2 [11.5 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic/main amd64 notification-daemon amd64 3.20.0-3 [36.9 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic/universe amd64 pstoedit amd64 3.70-5 [102 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texinfo amd64 6.5.0.dfsg.1-2 [752 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic/main amd64 libauthen-sasl-perl all 2.1600-1 [48.7 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libosmesa6 amd64 19.0.2-1ubuntu1.1~18.04.2 [2,473 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic/universe amd64 octave-common all 4.2.2-1ubuntu1 [1,444 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic/universe amd64 octave amd64 4.2.2-1ubuntu1 [1,583 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic/universe amd64 octave-doc all 4.2.2-1ubuntu1 [6,836 kB]
# Fetched 53.4 MB in 7s (8,171 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package install-info.
# (Reading database ... 131289 files and directories currently installed.)
# Preparing to unpack .../install-info_6.5.0.dfsg.1-2_amd64.deb ...
# Unpacking install-info (6.5.0.dfsg.1-2) ...
# Setting up install-info (6.5.0.dfsg.1-2) ...
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 131302 files and directories currently installed.)
# Preparing to unpack .../000-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../001-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../002-imagemagick-6-common_8%3a6.9.7.4+dfsg-16ubuntu6.7_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.7) ...
# Selecting previously unselected package libmagickcore-6.q16-3:amd64.
# Preparing to unpack .../003-libmagickcore-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.7_amd64.deb ...
# Unpacking libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.7) ...
# Selecting previously unselected package libmagickwand-6.q16-3:amd64.
# Preparing to unpack .../004-libmagickwand-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.7_amd64.deb ...
# Unpacking libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.7) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../005-libqt5svg5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../006-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../007-tex-common_6.09_all.deb ...
# Unpacking tex-common (6.09) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../008-netbase_5.4_all.deb ...
# Unpacking netbase (5.4) ...
# Selecting previously unselected package info.
# Preparing to unpack .../009-info_6.5.0.dfsg.1-2_amd64.deb ...
# Unpacking info (6.5.0.dfsg.1-2) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../010-libcupsimage2_2.2.7-1ubuntu2.6_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.6) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../011-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../012-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../013-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.9_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.9) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../014-libgs9_9.26~dfsg+0-0ubuntu0.18.04.9_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.9) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../015-ghostscript_9.26~dfsg+0-0ubuntu0.18.04.9_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.9) ...
# Selecting previously unselected package epstool.
# Preparing to unpack .../016-epstool_3.08+repack-7_amd64.deb ...
# Unpacking epstool (3.08+repack-7) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../017-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package aglfn.
# Preparing to unpack .../018-aglfn_1.7-3_all.deb ...
# Unpacking aglfn (1.7-3) ...
# Selecting previously unselected package gnuplot-data.
# Preparing to unpack .../019-gnuplot-data_5.2.2+dfsg1-2ubuntu1_all.deb ...
# Unpacking gnuplot-data (5.2.2+dfsg1-2ubuntu1) ...
# Selecting previously unselected package liblua5.3-0:amd64.
# Preparing to unpack .../020-liblua5.3-0_5.3.3-1ubuntu0.18.04.1_amd64.deb ...
# Unpacking liblua5.3-0:amd64 (5.3.3-1ubuntu0.18.04.1) ...
# Selecting previously unselected package libwxbase3.0-0v5:amd64.
# Preparing to unpack .../021-libwxbase3.0-0v5_3.0.4+dfsg-3_amd64.deb ...
# Unpacking libwxbase3.0-0v5:amd64 (3.0.4+dfsg-3) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../022-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../023-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../024-libnotify4_0.7.7-3_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.7-3) ...
# Selecting previously unselected package libwxgtk3.0-0v5:amd64.
# Preparing to unpack .../025-libwxgtk3.0-0v5_3.0.4+dfsg-3_amd64.deb ...
# Unpacking libwxgtk3.0-0v5:amd64 (3.0.4+dfsg-3) ...
# Selecting previously unselected package gnuplot-qt.
# Preparing to unpack .../026-gnuplot-qt_5.2.2+dfsg1-2ubuntu1_amd64.deb ...
# Unpacking gnuplot-qt (5.2.2+dfsg1-2ubuntu1) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../027-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../028-libsuitesparseconfig5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../029-libamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../030-libcamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../031-libccolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../032-libcolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../033-libmetis5_5.1.0.dfsg-5_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-5) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../034-libcholmod3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../035-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../036-libcxsparse3_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libdata-dump-perl.
# Preparing to unpack .../037-libdata-dump-perl_1.23-1_all.deb ...
# Unpacking libdata-dump-perl (1.23-1) ...
# Selecting previously unselected package libemf1:amd64.
# Preparing to unpack .../038-libemf1_1.0.9+git.10.3231442-1_amd64.deb ...
# Unpacking libemf1:amd64 (1.0.9+git.10.3231442-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../039-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../040-libfftw3-single3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../041-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../042-libhttp-date-perl_6.02-1_all.deb ...
# Unpacking libhttp-date-perl (6.02-1) ...
# Selecting previously unselected package libfile-listing-perl.
# Preparing to unpack .../043-libfile-listing-perl_6.04-1_all.deb ...
# Unpacking libfile-listing-perl (6.04-1) ...
# Selecting previously unselected package libfltk1.3:amd64.
# Preparing to unpack .../044-libfltk1.3_1.3.4-6_amd64.deb ...
# Unpacking libfltk1.3:amd64 (1.3.4-6) ...
# Selecting previously unselected package libfltk-gl1.3:amd64.
# Preparing to unpack .../045-libfltk-gl1.3_1.3.4-6_amd64.deb ...
# Unpacking libfltk-gl1.3:amd64 (1.3.4-6) ...
# Selecting previously unselected package libfont-afm-perl.
# Preparing to unpack .../046-libfont-afm-perl_1.20-2_all.deb ...
# Unpacking libfont-afm-perl (1.20-2) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../047-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../048-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libglpk40:amd64.
# Preparing to unpack .../049-libglpk40_4.65-1_amd64.deb ...
# Unpacking libglpk40:amd64 (4.65-1) ...
# Selecting previously unselected package libwmf0.2-7:amd64.
# Preparing to unpack .../050-libwmf0.2-7_0.2.8.4-12_amd64.deb ...
# Unpacking libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Selecting previously unselected package libgraphicsmagick-q16-3.
# Preparing to unpack .../051-libgraphicsmagick-q16-3_1.3.28-2_amd64.deb ...
# Unpacking libgraphicsmagick-q16-3 (1.3.28-2) ...
# Selecting previously unselected package libgraphicsmagick++-q16-12.
# Preparing to unpack .../052-libgraphicsmagick++-q16-12_1.3.28-2_amd64.deb ...
# Unpacking libgraphicsmagick++-q16-12 (1.3.28-2) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../053-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../054-libhtml-tagset-perl_3.20-3_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-3) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../055-liburi-perl_1.73-1_all.deb ...
# Unpacking liburi-perl (1.73-1) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../056-libhtml-parser-perl_3.72-3build1_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-3build1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../057-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../058-liblwp-mediatypes-perl_6.02-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.02-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../059-libhttp-message-perl_6.14-1_all.deb ...
# Unpacking libhttp-message-perl (6.14-1) ...
# Selecting previously unselected package libhtml-form-perl.
# Preparing to unpack .../060-libhtml-form-perl_6.03-1_all.deb ...
# Unpacking libhtml-form-perl (6.03-1) ...
# Selecting previously unselected package libhtml-tree-perl.
# Preparing to unpack .../061-libhtml-tree-perl_5.07-1_all.deb ...
# Unpacking libhtml-tree-perl (5.07-1) ...
# Selecting previously unselected package libhtml-format-perl.
# Preparing to unpack .../062-libhtml-format-perl_2.12-1_all.deb ...
# Unpacking libhtml-format-perl (2.12-1) ...
# Selecting previously unselected package libhttp-cookies-perl.
# Preparing to unpack .../063-libhttp-cookies-perl_6.04-1_all.deb ...
# Unpacking libhttp-cookies-perl (6.04-1) ...
# Selecting previously unselected package libhttp-daemon-perl.
# Preparing to unpack .../064-libhttp-daemon-perl_6.01-1_all.deb ...
# Unpacking libhttp-daemon-perl (6.01-1) ...
# Selecting previously unselected package libhttp-negotiate-perl.
# Preparing to unpack .../065-libhttp-negotiate-perl_6.00-2_all.deb ...
# Unpacking libhttp-negotiate-perl (6.00-2) ...
# Selecting previously unselected package perl-openssl-defaults:amd64.
# Preparing to unpack .../066-perl-openssl-defaults_3build1_amd64.deb ...
# Unpacking perl-openssl-defaults:amd64 (3build1) ...
# Selecting previously unselected package libnet-ssleay-perl.
# Preparing to unpack .../067-libnet-ssleay-perl_1.84-1ubuntu0.1_amd64.deb ...
# Unpacking libnet-ssleay-perl (1.84-1ubuntu0.1) ...
# Selecting previously unselected package libio-socket-ssl-perl.
# Preparing to unpack .../068-libio-socket-ssl-perl_2.060-3~ubuntu18.04.1_all.deb ...
# Unpacking libio-socket-ssl-perl (2.060-3~ubuntu18.04.1) ...
# Selecting previously unselected package libnet-http-perl.
# Preparing to unpack .../069-libnet-http-perl_6.17-1_all.deb ...
# Unpacking libnet-http-perl (6.17-1) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../070-libtry-tiny-perl_0.30-1_all.deb ...
# Unpacking libtry-tiny-perl (0.30-1) ...
# Selecting previously unselected package libwww-robotrules-perl.
# Preparing to unpack .../071-libwww-robotrules-perl_6.01-1_all.deb ...
# Unpacking libwww-robotrules-perl (6.01-1) ...
# Selecting previously unselected package libwww-perl.
# Preparing to unpack .../072-libwww-perl_6.31-1ubuntu0.1_all.deb ...
# Unpacking libwww-perl (6.31-1ubuntu0.1) ...
# Selecting previously unselected package liblwp-protocol-https-perl.
# Preparing to unpack .../073-liblwp-protocol-https-perl_6.07-2_all.deb ...
# Unpacking liblwp-protocol-https-perl (6.07-2) ...
# Selecting previously unselected package libmagick++-6.q16-7:amd64.
# Preparing to unpack .../074-libmagick++-6.q16-7_8%3a6.9.7.4+dfsg-16ubuntu6.7_amd64.deb ...
# Unpacking libmagick++-6.q16-7:amd64 (8:6.9.7.4+dfsg-16ubuntu6.7) ...
# Selecting previously unselected package libnet-smtp-ssl-perl.
# Preparing to unpack .../075-libnet-smtp-ssl-perl_1.04-1_all.deb ...
# Unpacking libnet-smtp-ssl-perl (1.04-1) ...
# Selecting previously unselected package libmailtools-perl.
# Preparing to unpack .../076-libmailtools-perl_2.18-1_all.deb ...
# Unpacking libmailtools-perl (2.18-1) ...
# Selecting previously unselected package libqrupdate1:amd64.
# Preparing to unpack .../077-libqrupdate1_1.1.2-2build1_amd64.deb ...
# Unpacking libqrupdate1:amd64 (1.1.2-2build1) ...
# Selecting previously unselected package libumfpack5:amd64.
# Preparing to unpack .../078-libumfpack5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libumfpack5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package liboctave4:amd64.
# Preparing to unpack .../079-liboctave4_4.2.2-1ubuntu1_amd64.deb ...
# Unpacking liboctave4:amd64 (4.2.2-1ubuntu1) ...
# Selecting previously unselected package libplot2c2:amd64.
# Preparing to unpack .../080-libplot2c2_2.6-9_amd64.deb ...
# Unpacking libplot2c2:amd64 (2.6-9) ...
# Selecting previously unselected package libportaudio2:amd64.
# Preparing to unpack .../081-libportaudio2_19.6.0-1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1) ...
# Selecting previously unselected package libzip4:amd64.
# Preparing to unpack .../082-libzip4_1.1.2-1.1_amd64.deb ...
# Unpacking libzip4:amd64 (1.1.2-1.1) ...
# Selecting previously unselected package libpstoedit0c2a.
# Preparing to unpack .../083-libpstoedit0c2a_3.70-5_amd64.deb ...
# Unpacking libpstoedit0c2a (3.70-5) ...
# Selecting previously unselected package libqscintilla2-qt5-l10n.
# Preparing to unpack .../084-libqscintilla2-qt5-l10n_2.10.2+dfsg-4_all.deb ...
# Unpacking libqscintilla2-qt5-l10n (2.10.2+dfsg-4) ...
# Selecting previously unselected package libqscintilla2-qt5-13.
# Preparing to unpack .../085-libqscintilla2-qt5-13_2.10.2+dfsg-4_amd64.deb ...
# Unpacking libqscintilla2-qt5-13 (2.10.2+dfsg-4) ...
# Selecting previously unselected package libqt5opengl5:amd64.
# Preparing to unpack .../086-libqt5opengl5_5.9.5+dfsg-0ubuntu2.1_amd64.deb ...
# Unpacking libqt5opengl5:amd64 (5.9.5+dfsg-0ubuntu2.1) ...
# Selecting previously unselected package libtext-unidecode-perl.
# Preparing to unpack .../087-libtext-unidecode-perl_1.30-1_all.deb ...
# Unpacking libtext-unidecode-perl (1.30-1) ...
# Selecting previously unselected package libxml-namespacesupport-perl.
# Preparing to unpack .../088-libxml-namespacesupport-perl_1.12-1_all.deb ...
# Unpacking libxml-namespacesupport-perl (1.12-1) ...
# Selecting previously unselected package libxml-sax-base-perl.
# Preparing to unpack .../089-libxml-sax-base-perl_1.09-1_all.deb ...
# Unpacking libxml-sax-base-perl (1.09-1) ...
# Selecting previously unselected package libxml-sax-perl.
# Preparing to unpack .../090-libxml-sax-perl_0.99+dfsg-2ubuntu1_all.deb ...
# Unpacking libxml-sax-perl (0.99+dfsg-2ubuntu1) ...
# Selecting previously unselected package libxml-libxml-perl.
# Preparing to unpack .../091-libxml-libxml-perl_2.0128+dfsg-5_amd64.deb ...
# Unpacking libxml-libxml-perl (2.0128+dfsg-5) ...
# Selecting previously unselected package libxml-parser-perl.
# Preparing to unpack .../092-libxml-parser-perl_2.44-2build3_amd64.deb ...
# Unpacking libxml-parser-perl (2.44-2build3) ...
# Selecting previously unselected package libxml-sax-expat-perl.
# Preparing to unpack .../093-libxml-sax-expat-perl_0.40-2_all.deb ...
# Unpacking libxml-sax-expat-perl (0.40-2) ...
# Selecting previously unselected package notification-daemon.
# Preparing to unpack .../094-notification-daemon_3.20.0-3_amd64.deb ...
# Unpacking notification-daemon (3.20.0-3) ...
# Selecting previously unselected package pstoedit.
# Preparing to unpack .../095-pstoedit_3.70-5_amd64.deb ...
# Unpacking pstoedit (3.70-5) ...
# Selecting previously unselected package texinfo.
# Preparing to unpack .../096-texinfo_6.5.0.dfsg.1-2_amd64.deb ...
# Unpacking texinfo (6.5.0.dfsg.1-2) ...
# Selecting previously unselected package libauthen-sasl-perl.
# Preparing to unpack .../097-libauthen-sasl-perl_2.1600-1_all.deb ...
# Unpacking libauthen-sasl-perl (2.1600-1) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../098-libosmesa6_19.0.2-1ubuntu1.1~18.04.2_amd64.deb ...
# Unpacking libosmesa6:amd64 (19.0.2-1ubuntu1.1~18.04.2) ...
# Selecting previously unselected package octave-common.
# Preparing to unpack .../099-octave-common_4.2.2-1ubuntu1_all.deb ...
# Unpacking octave-common (4.2.2-1ubuntu1) ...
# Selecting previously unselected package octave.
# Preparing to unpack .../100-octave_4.2.2-1ubuntu1_amd64.deb ...
# Unpacking octave (4.2.2-1ubuntu1) ...
# Selecting previously unselected package octave-doc.
# Preparing to unpack .../101-octave-doc_4.2.2-1ubuntu1_all.deb ...
# Unpacking octave-doc (4.2.2-1ubuntu1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.9) ...
# Setting up libhtml-tagset-perl (3.20-3) ...
# Setting up imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.7) ...
# Setting up libnotify4:amd64 (0.7.7-3) ...
# Setting up libcxsparse3:amd64 (1:5.1.2-2) ...
# Setting up libtry-tiny-perl (0.30-1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libfont-afm-perl (1.20-2) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up info (6.5.0.dfsg.1-2) ...
# update-alternatives: using /usr/bin/info to provide /usr/bin/infobrowser (infobrowser) in auto mode
# Setting up libportaudio2:amd64 (19.6.0-1) ...
# Setting up tex-common (6.09) ...
# update-language: texlive-base not installed and configured, doing nothing!
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up libxml-namespacesupport-perl (1.12-1) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up poppler-data (0.4.8-2) ...
# Processing triggers for install-info (6.5.0.dfsg.1-2) ...
# Setting up perl-openssl-defaults:amd64 (3build1) ...
# Setting up libosmesa6:amd64 (19.0.2-1ubuntu1.1~18.04.2) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up libtext-unidecode-perl (1.30-1) ...
# Setting up libqt5opengl5:amd64 (5.9.5+dfsg-0ubuntu2.1) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up libwxbase3.0-0v5:amd64 (3.0.4+dfsg-3) ...
# Setting up libqrupdate1:amd64 (1.1.2-2build1) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libzip4:amd64 (1.1.2-1.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.6) ...
# Setting up libxml-sax-base-perl (1.09-1) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Setting up liblwp-mediatypes-perl (6.02-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up liburi-perl (1.73-1) ...
# Setting up libqt5svg5:amd64 (5.9.5-0ubuntu1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-5) ...
# Setting up libdata-dump-perl (1.23-1) ...
# Setting up libhtml-parser-perl (3.72-3build1) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Setting up libcolamd2:amd64 (1:5.1.2-2) ...
# Setting up libfltk1.3:amd64 (1.3.4-6) ...
# Setting up libccolamd2:amd64 (1:5.1.2-2) ...
# Setting up libfftw3-single3:amd64 (3.3.7-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up octave-common (4.2.2-1ubuntu1) ...
# Setting up libnet-http-perl (6.17-1) ...
# Setting up libqscintilla2-qt5-l10n (2.10.2+dfsg-4) ...
# Setting up libemf1:amd64 (1.0.9+git.10.3231442-1) ...
# Setting up aglfn (1.7-3) ...
# Setting up libplot2c2:amd64 (2.6-9) ...
# Setting up liblua5.3-0:amd64 (5.3.3-1ubuntu0.18.04.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.9) ...
# Setting up libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Setting up libwww-robotrules-perl (6.01-1) ...
# Setting up libauthen-sasl-perl (2.1600-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Setting up notification-daemon (3.20.0-3) ...
# Setting up octave-doc (4.2.2-1ubuntu1) ...
# Setting up netbase (5.4) ...
# Setting up libxml-sax-perl (0.99+dfsg-2ubuntu1) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::SAX::PurePerl with priority 10...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
#
# Creating config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libhttp-date-perl (6.02-1) ...
# Setting up libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.7) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up libnet-ssleay-perl (1.84-1ubuntu0.1) ...
# Setting up libfltk-gl1.3:amd64 (1.3.4-6) ...
# Setting up libcamd2:amd64 (1:5.1.2-2) ...
# Setting up libqscintilla2-qt5-13 (2.10.2+dfsg-4) ...
# Setting up libwxgtk3.0-0v5:amd64 (3.0.4+dfsg-3) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.9) ...
# Setting up gnuplot-data (5.2.2+dfsg1-2ubuntu1) ...
# Setting up libio-socket-ssl-perl (2.060-3~ubuntu18.04.1) ...
# Setting up libgraphicsmagick-q16-3 (1.3.28-2) ...
# Setting up libhtml-tree-perl (5.07-1) ...
# Setting up libamd2:amd64 (1:5.1.2-2) ...
# Setting up libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.7) ...
# Setting up libfile-listing-perl (6.04-1) ...
# Setting up libhttp-message-perl (6.14-1) ...
# Setting up libxml-libxml-perl (2.0128+dfsg-5) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::LibXML::SAX::Parser with priority 50...
# update-perl-sax-parsers: Registering Perl SAX parser XML::LibXML::SAX with priority 50...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# Replacing config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up libhttp-negotiate-perl (6.00-2) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libgraphicsmagick++-q16-12 (1.3.28-2) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up libhtml-format-perl (2.12-1) ...
# Setting up libglpk40:amd64 (4.65-1) ...
# Setting up libhttp-cookies-perl (6.04-1) ...
# Setting up gnuplot-qt (5.2.2+dfsg1-2ubuntu1) ...
# update-alternatives: using /usr/bin/gnuplot-qt to provide /usr/bin/gnuplot (gnuplot) in auto mode
# Setting up epstool (3.08+repack-7) ...
# Setting up libhttp-daemon-perl (6.01-1) ...
# Setting up libcholmod3:amd64 (1:5.1.2-2) ...
# Setting up libmagick++-6.q16-7:amd64 (8:6.9.7.4+dfsg-16ubuntu6.7) ...
# Setting up libpstoedit0c2a (3.70-5) ...
# Setting up libhtml-form-perl (6.03-1) ...
# Setting up texinfo (6.5.0.dfsg.1-2) ...
# Setting up libmailtools-perl (2.18-1) ...
# Setting up libumfpack5:amd64 (1:5.1.2-2) ...
# Setting up pstoedit (3.70-5) ...
# Setting up liboctave4:amd64 (4.2.2-1ubuntu1) ...
# Setting up octave (4.2.2-1ubuntu1) ...
# Setting up liblwp-protocol-https-perl (6.07-2) ...
# Setting up libwww-perl (6.31-1ubuntu0.1) ...
# Setting up libxml-parser-perl (2.44-2build3) ...
# Setting up libxml-sax-expat-perl (0.40-2) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::SAX::Expat with priority 50...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# Replacing config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
# !apt-get install liboctave-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libfftw3-bin libfftw3-dev libfftw3-long3 libfftw3-quad3
# Suggested packages:
#   libfftw3-doc
# The following NEW packages will be installed:
#   libfftw3-bin libfftw3-dev libfftw3-long3 libfftw3-quad3 liboctave-dev
# 0 upgraded, 5 newly installed, 0 to remove and 4 not upgraded.
# Need to get 3,439 kB of archives.
# After this operation, 23.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-long3 amd64 3.3.7-1 [308 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-quad3 amd64 3.3.7-1 [552 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-bin amd64 3.3.7-1 [32.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-dev amd64 3.3.7-1 [2,108 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liboctave-dev amd64 4.2.2-1ubuntu1 [438 kB]
# Fetched 3,439 kB in 2s (1,720 kB/s)
# Selecting previously unselected package libfftw3-long3:amd64.
# (Reading database ... 139028 files and directories currently installed.)
# Preparing to unpack .../libfftw3-long3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../libfftw3-quad3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../libfftw3-bin_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-bin (3.3.7-1) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../libfftw3-dev_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.7-1) ...
# Selecting previously unselected package liboctave-dev.
# Preparing to unpack .../liboctave-dev_4.2.2-1ubuntu1_amd64.deb ...
# Unpacking liboctave-dev (4.2.2-1ubuntu1) ...
# Setting up libfftw3-quad3:amd64 (3.3.7-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up libfftw3-long3:amd64 (3.3.7-1) ...
# Setting up libfftw3-bin (3.3.7-1) ...
# Setting up libfftw3-dev:amd64 (3.3.7-1) ...
# Setting up liboctave-dev (4.2.2-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %% [markdown]
# install image package: pkg install -forge image

# %%
# !octave
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# GNU Octave, version 4.2.2
# Copyright (C) 2018 John W. Eaton and others.
# This is free software; see the source code for copying conditions.
# There is ABSOLUTELY NO WARRANTY; not even for MERCHANTABILITY or
# FITNESS FOR A PARTICULAR PURPOSE.  For details, type 'warranty'.
#
# Octave was configured for "x86_64-pc-linux-gnu".
#
# Additional information about Octave is available at http://www.octave.org.
#
# Please contribute if you find this software useful.
# For more information, visit http://www.octave.org/get-involved.html
#
# Read http://www.octave.org/bugs.html to learn how to submit bug reports.
# For information about changes from previous versions, type 'news'.
#
# octave:1> pkg install -forge image
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# quit
# For information about changes from previous versions of the image package, run 'news image'.
# octave:2> quit

# %% [markdown]
# # prepare data in pose/segment/women_top

# %%
# !tar zxf /content/drive/My\ Drive/VITON/zalando_dataset/segment.tar.gz -C data
# !tar xf /content/drive/My\ Drive/VITON/zalando_dataset/pose.tar.gz -C data

# %%
# !tar zxf /content/drive/My\ Drive/VITON/processed_data_in_CP_VITON/viton_resize.tar.gz

# %%
# !cp viton_resize/test/cloth/* data/women_top/
# !cp viton_resize/test/image/* data/women_top/

# %%
import os
path = '/content/drive/My Drive/VITON/VITON/data/women_top'
# path = 'viton_resize/test/image'
for name in os.listdir(path)[:5]:
  print(name)
  
len(os.listdir(path))
# Out:
# 009967_0.jpg
# 009975_0.jpg
# 009984_0.jpg
# 009995_0.jpg
# 010003_0.jpg
# 4065

# %% [markdown]
# # Test

# %% [markdown]
# ## First stage

# %% [markdown]
# 准备data/viton_test_pairs.txt，让column1模特穿上column2衣服，格式如下：

# %%
000010_0.jpg 000010_1.jpg
000001_0.jpg 000010_1.jpg

# %%
top
/content/VITON/viton_resize/test/cloth/000010_1.jpg
/content/VITON/viton_resize/test/cloth/000010_1.jpg

model
/content/VITON/viton_resize/test/image/000010_0.jpg
/content/VITON/viton_resize/test/image/000001_0.jpg

# %%
top_list = os.listdir('viton_resize/test/cloth')
model_list = os.listdir('viton_resize/test/image')
import random
random.shuffle(top_list)
random.shuffle(model_list)
print(len(top_list))
print(len(model_list))
# Out:
# 2032
# 2032

# %%
with open('data/viton_test_pairs.txt', 'w') as f:
  content = ''
  for i, (model, top) in  enumerate(zip(model_list, top_list)):
    if i>=30: break
    content += model + ' ' + top + '\n'
  f.writelines(content)

# %%
# !cat data/viton_test_pairs.txt
# Out:
# 017722_0.jpg 000154_1.jpg
# 014574_0.jpg 010011_1.jpg
# 003414_0.jpg 004107_1.jpg
# 017536_0.jpg 006678_1.jpg
# 015516_0.jpg 010244_1.jpg
# 001236_0.jpg 013106_1.jpg
# 015881_0.jpg 018910_1.jpg
# 005285_0.jpg 005388_1.jpg
# 001776_0.jpg 003591_1.jpg
# 004220_0.jpg 010984_1.jpg
# 017770_0.jpg 017945_1.jpg
# 001320_0.jpg 004158_1.jpg
# 015150_0.jpg 015990_1.jpg
# 004478_0.jpg 008663_1.jpg
# 018544_0.jpg 012626_1.jpg
# 005809_0.jpg 018112_1.jpg
# 012660_0.jpg 012849_1.jpg
# 014528_0.jpg 015371_1.jpg
# 000685_0.jpg 016059_1.jpg
# 014701_0.jpg 011288_1.jpg
# 014252_0.jpg 009399_1.jpg
# 013199_0.jpg 007789_1.jpg
# 009595_0.jpg 008771_1.jpg
# 004997_0.jpg 004071_1.jpg
# 019119_0.jpg 005562_1.jpg
# 013968_0.jpg 001635_1.jpg
# 004833_0.jpg 017153_1.jpg
# 007719_0.jpg 009178_1.jpg
# 011745_0.jpg 014240_1.jpg
# 007086_0.jpg 015707_1.jpg

# %% [markdown]
# inference

# %%
# !bash test_stage1.sh  # single img

# %%
# !python model_zalando_mask_content_test.py \
  --checkpoint model/stage1/model-15000 \
  --mode test \
  --result_dir results/stage1/ \
  --begin 0 \
  --end 30 #exclusive
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0811 07:26:53.173334 139646869792640 deprecation_wrapper.py:119] From /content/drive/My Drive/VITON/VITON/model_zalando_mask_content.py:81: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0811 07:26:53.173639 139646869792640 deprecation_wrapper.py:119] From /content/drive/My Drive/VITON/VITON/model_zalando_mask_content.py:81: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0811 07:26:53.174637 139646869792640 deprecation_wrapper.py:119] From model_zalando_mask_content_test.py:230: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0811 07:26:53.181331 139646869792640 deprecation_wrapper.py:119] From model_zalando_mask_content_test.py:123: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0811 07:26:53.230492 139646869792640 deprecation_wrapper.py:119] From model_zalando_mask_content_test.py:132: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0811 07:26:53.235920 139646869792640 deprecation_wrapper.py:119] From /content/drive/My Drive/VITON/VITON/utils.py:384: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0811 07:26:53.620736 139646869792640 deprecation_wrapper.py:119] From model_zalando_mask_content_test.py:142: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0811 07:26:53.684226 139646869792640 deprecation_wrapper.py:119] From model_zalando_mask_content_test.py:143: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-08-11 07:26:53.685874: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-08-11 07:26:53.736210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:53.736684: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-08-11 07:26:53.739247: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-11 07:26:53.921812: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-11 07:26:54.008377: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-11 07:26:54.026928: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-11 07:26:54.230435: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-11 07:26:54.347264: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-11 07:26:54.724378: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-11 07:26:54.724613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:54.725136: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:54.725575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-11 07:26:54.750049: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-08-11 07:26:54.753520: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x68fe540 executing computations on platform Host. Devices:
# 2019-08-11 07:26:54.753561: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-08-11 07:26:54.873106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:54.873663: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x68fec40 executing computations on platform CUDA. Devices:
# 2019-08-11 07:26:54.873700: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-08-11 07:26:54.873907: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:54.874318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-08-11 07:26:54.874388: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-11 07:26:54.874424: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-11 07:26:54.874459: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-11 07:26:54.874512: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-11 07:26:54.874548: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-11 07:26:54.874580: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-11 07:26:54.874613: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-11 07:26:54.874693: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:54.875107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:54.875494: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-11 07:26:54.879771: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-11 07:26:54.881980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-11 07:26:54.882018: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-11 07:26:54.882040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-11 07:26:54.886963: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:54.887460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:26:54.887969: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:40] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-08-11 07:26:54.888027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10802 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# loading model from checkpoint
# model/stage1/model-15000
# W0811 07:26:55.073970 139646869792640 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# I0811 07:26:55.080120 139646869792640 saver.py:1280] Restoring parameters from model/stage1/model-15000
# ['017722_0.jpg', '000154_1.jpg']
# W0811 07:27:05.126552 139646869792640 deprecation_wrapper.py:119] From /content/drive/My Drive/VITON/VITON/utils.py:75: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# 2019-08-11 07:27:05.391616: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# ['014574_0.jpg', '010011_1.jpg']
# ['003414_0.jpg', '004107_1.jpg']
# ['017536_0.jpg', '006678_1.jpg']
# ['015516_0.jpg', '010244_1.jpg']
# ['001236_0.jpg', '013106_1.jpg']
# ['015881_0.jpg', '018910_1.jpg']
# ['005285_0.jpg', '005388_1.jpg']
# ['001776_0.jpg', '003591_1.jpg']
# ['004220_0.jpg', '010984_1.jpg']
# ['017770_0.jpg', '017945_1.jpg']
# ['001320_0.jpg', '004158_1.jpg']
# ['015150_0.jpg', '015990_1.jpg']
# ['004478_0.jpg', '008663_1.jpg']
# ['018544_0.jpg', '012626_1.jpg']
# ['005809_0.jpg', '018112_1.jpg']
# ['012660_0.jpg', '012849_1.jpg']
# ['014528_0.jpg', '015371_1.jpg']
# ['000685_0.jpg', '016059_1.jpg']
# ['014701_0.jpg', '011288_1.jpg']
# ['014252_0.jpg', '009399_1.jpg']
# ['013199_0.jpg', '007789_1.jpg']
# ['009595_0.jpg', '008771_1.jpg']
# ['004997_0.jpg', '004071_1.jpg']
# ['019119_0.jpg', '005562_1.jpg']
# ['013968_0.jpg', '001635_1.jpg']
# ['004833_0.jpg', '017153_1.jpg']
# ['007719_0.jpg', '009178_1.jpg']
# ['011745_0.jpg', '014240_1.jpg']
# ['007086_0.jpg', '015707_1.jpg']

# %% [markdown]
# # Second stage

# %% [markdown]
# Run the matlab script shape_context_warp.m to extract the TPS transformation control points.

# %%
# %%writefile shape_context_warp_30.m
# % Xintong Han 2017
# % Perform TPS transformation using the masks output by the first stage
# % Code for shape context matching (under shape_context folder) are modified from:
# % https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/shape/sc_digits.html
#
# addpath('shape_context')
# DATA_ROOT='data/women_top/';
# MASK_DIR='results/stage1/tps/00015000_';
#
# % Check if using MATLAB or Octave
# isOctave = exist('OCTAVE_VERSION', 'builtin') ~= 0;
# if(isOctave)
#   % Load image package for resizing images
#   pkg load image;
#   % Turn off warning
#   warning('off', 'Octave:possible-matlab-short-circuit-operator');
# end
#
# [image1, image2] = textread('data/viton_test_pairs.txt', '%s %s\n');
# % using a smaller height and width for the shape context matching
# % can save time without hurting the perform too much.
# h = 256/4;
# w = 192/4;
# % we use 10x10 control_points
# n_control = 10;
# for i = 1:30 %length(image1) % only run over 1 image (for now)
#     image_name1 = image1{i};
#     image_name2 = image2{i};
#     if exist([MASK_DIR, image_name1, '_', image_name2, '_tps.mat'])
#         continue
#     end
#     V1 = imread([DATA_ROOT, image_name2]);
#     [h0, w0, ~] = size(V1);
#     orig_im = imresize(im2double(V1), [h,w]);
#     % extract fashion item masks
#     V1 = V1(:,:,1) ~= 255 & V1(:,:,2) ~= 255 & V1(:,:,3) ~= 255;
#     V1 = imresize(double(V1), [h,w], 'nearest');
#     V1 = imfill(V1);
#     V1 = medfilt2(V1);
#     % Load product mask of image.
#     V2 = load([MASK_DIR, image_name1, '_', image_name2, '_mask.mat']);
#     V2 = imresize(double(V2.mask), [h,w]);
#     % TPS transformation
#     try
#         tic;[keypoints1, keypoints2, warp_points0, warp_im] = tps_main(V1, V2, n_control, orig_im, 0);toc;
#     catch
#         % when there is not enough keypoints for estimating the TPS
#         % transformation
#         'not enough keypoints'
#         continue
#     end
#     keypoints1 = [keypoints1(:,2) / h, keypoints1(:,1) / w];
#     keypoints2 = [keypoints2(:,2) / h, keypoints2(:,1) / w];
#     warp_points = [warp_points0(1,:); warp_points0(2,:)];
#     [gx, gy] = meshgrid(linspace(1,w,n_control), linspace(1,h,n_control));
#     gx = gx(:); gy = gy(:);
#     [x,y] = meshgrid(linspace(-2*w,2*w,4*w+1),linspace(-2*h,2*h,4*h+1));
#     x=x(:); y=y(:);
#     % nn of each point
#     point_distance = dist2([gx,gy], warp_points');
#     [~, point_index] = min(point_distance, [], 2);
#     control_points = [x(point_index), y(point_index)]';
#     control_points = [control_points(1,:) / w; control_points(2,:) / h];
#     control_points = reshape(control_points, [2,n_control,n_control]);
#     save([MASK_DIR, image_name1, '_', image_name2, '_tps.mat'], 'control_points', '-v6');
# end
# Out:
# Overwriting shape_context_warp_30.m

# %%
# !octave -W shape_context_warp.m  # single img

# %%
# !octave -W shape_context_warp_30.m
# Out:
# Elapsed time is 18.4306 seconds.
# Elapsed time is 18.6915 seconds.
# Elapsed time is 19.5076 seconds.
# Elapsed time is 18.1924 seconds.
# Elapsed time is 19.9096 seconds.
# Elapsed time is 19.6949 seconds.
# Elapsed time is 20.158 seconds.
# Elapsed time is 19.4951 seconds.
# Elapsed time is 20.1187 seconds.
# Elapsed time is 19.9577 seconds.
# Elapsed time is 19.9577 seconds.
# Elapsed time is 18.4968 seconds.
# Elapsed time is 19.5902 seconds.
# Elapsed time is 19.9877 seconds.
# Elapsed time is 19.7927 seconds.
# Elapsed time is 20.2528 seconds.
# Elapsed time is 15.4848 seconds.
# Elapsed time is 17.2716 seconds.
# Elapsed time is 21.2543 seconds.
# Elapsed time is 20.3968 seconds.
# Elapsed time is 17.6486 seconds.

# %% [markdown]
# Then test_stage2.sh will do the refinement and generate the final results, which locates in results/stage2/images/. results/stage2/index.html visualizes the results.

# %%
# !bash test_stage2.sh # for single img

# %%
# for multi img
# !python model_zalando_refine_test.py \
  --coarse_result_dir results/stage1/ \
  --checkpoint model/stage2/model-6000 \
  --mode test \
  --result_dir results/stage2/ \
  --begin 0 \
  --end 30 #exclusive
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0811 07:47:09.243587 139686195042176 deprecation_wrapper.py:119] From /content/drive/My Drive/VITON/VITON/model_zalando_tps_warp.py:84: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0811 07:47:09.243896 139686195042176 deprecation_wrapper.py:119] From /content/drive/My Drive/VITON/VITON/model_zalando_tps_warp.py:84: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0811 07:47:09.245205 139686195042176 deprecation_wrapper.py:119] From model_zalando_refine_test.py:251: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0811 07:47:09.251944 139686195042176 deprecation_wrapper.py:119] From model_zalando_refine_test.py:129: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0811 07:47:09.256739 139686195042176 deprecation_wrapper.py:119] From model_zalando_refine_test.py:135: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0811 07:47:09.259493 139686195042176 deprecation_wrapper.py:119] From /content/drive/My Drive/VITON/VITON/model_zalando_tps_warp.py:198: The name tf.image.resize_area is deprecated. Please use tf.compat.v1.image.resize_area instead.
#
# W0811 07:47:09.647420 139686195042176 deprecation_wrapper.py:119] From model_zalando_refine_test.py:142: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0811 07:47:09.647664 139686195042176 deprecation_wrapper.py:119] From model_zalando_refine_test.py:142: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0811 07:47:09.667718 139686195042176 deprecation_wrapper.py:119] From model_zalando_refine_test.py:144: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-08-11 07:47:09.669042: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-08-11 07:47:09.693234: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.693671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-08-11 07:47:09.693988: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-11 07:47:09.695496: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-11 07:47:09.705069: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-11 07:47:09.705526: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-11 07:47:09.707312: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-11 07:47:09.708926: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-11 07:47:09.716278: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-11 07:47:09.716437: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.716949: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.717378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-11 07:47:09.723695: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-08-11 07:47:09.723934: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x217ea00 executing computations on platform Host. Devices:
# 2019-08-11 07:47:09.723988: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-08-11 07:47:09.799319: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.799914: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x217ebc0 executing computations on platform CUDA. Devices:
# 2019-08-11 07:47:09.799951: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-08-11 07:47:09.800213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.800600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-08-11 07:47:09.800682: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-11 07:47:09.800730: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-11 07:47:09.800811: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-11 07:47:09.800867: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-11 07:47:09.800913: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-11 07:47:09.800956: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-11 07:47:09.800997: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-11 07:47:09.801135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.801625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.801990: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-11 07:47:09.802062: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-11 07:47:09.803325: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-11 07:47:09.803361: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-11 07:47:09.803379: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-11 07:47:09.803662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.804089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-11 07:47:09.804478: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:40] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-08-11 07:47:09.804533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10802 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# loading model from checkpoint
# model/stage2/model-6000
# W0811 07:47:09.989219 139686195042176 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# I0811 07:47:09.992138 139686195042176 saver.py:1280] Restoring parameters from model/stage2/model-6000
# 0
# ['017722_0.jpg', '000154_1.jpg']
# W0811 07:47:11.932614 139686195042176 deprecation_wrapper.py:119] From model_zalando_refine_test.py:66: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# W0811 07:47:12.073911 139686195042176 deprecation_wrapper.py:119] From /content/drive/My Drive/VITON/VITON/tps_transformer.py:133: The name tf.log is deprecated. Please use tf.math.log instead.
#
# 2019-08-11 07:47:12.883149: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-11 07:47:13.540110: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# 2019-08-11 07:47:13.555268: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 1
# ['014574_0.jpg', '010011_1.jpg']
# 2
# ['003414_0.jpg', '004107_1.jpg']
# 3
# ['017536_0.jpg', '006678_1.jpg']
# 4
# ['015516_0.jpg', '010244_1.jpg']
# 5
# ['001236_0.jpg', '013106_1.jpg']
# 6
# ['015881_0.jpg', '018910_1.jpg']
# 7
# ['005285_0.jpg', '005388_1.jpg']
# 8
# ['001776_0.jpg', '003591_1.jpg']
# 9
# ['004220_0.jpg', '010984_1.jpg']
# 10
# ['017770_0.jpg', '017945_1.jpg']
# 11
# ['001320_0.jpg', '004158_1.jpg']
# 12
# ['015150_0.jpg', '015990_1.jpg']
# 13
# ['004478_0.jpg', '008663_1.jpg']
# 14
# ['018544_0.jpg', '012626_1.jpg']
# 15
# ['005809_0.jpg', '018112_1.jpg']
# 16
# ['012660_0.jpg', '012849_1.jpg']
# 17
# ['014528_0.jpg', '015371_1.jpg']
# 18
# ['000685_0.jpg', '016059_1.jpg']
# 19
# ['014701_0.jpg', '011288_1.jpg']
# 20
# ['014252_0.jpg', '009399_1.jpg']
# 21
# ['013199_0.jpg', '007789_1.jpg']
# 22
# ['009595_0.jpg', '008771_1.jpg']
# 23
# ['004997_0.jpg', '004071_1.jpg']
# 24
# ['019119_0.jpg', '005562_1.jpg']
# 25
# ['013968_0.jpg', '001635_1.jpg']
# 26
# ['004833_0.jpg', '017153_1.jpg']
# 27
# ['007719_0.jpg', '009178_1.jpg']
# 28
# ['011745_0.jpg', '014240_1.jpg']
# 29
# ['007086_0.jpg', '015707_1.jpg']

# %%
import matplotlib.pyplot as plt
with open('data/viton_test_pairs.txt', 'r') as f:
  for i, line in enumerate(f.readlines()):
    if i>=10: break
    model, top = line.strip().split(' ')
    print(model, top)
    plt.subplot(131)
    plt.imshow(plt.imread(os.path.join('results/stage2/images', model)))
    plt.subplot(132)
    plt.imshow(plt.imread(os.path.join('results/stage2/images', top)))
    plt.subplot(133)
    plt.imshow(plt.imread(os.path.join('results/stage2/images', model + '_' +top+'_final.png')))
    plt.show()
# Out:
# 017722_0.jpg 000154_1.jpg
# 014574_0.jpg 010011_1.jpg
# 003414_0.jpg 004107_1.jpg
# 017536_0.jpg 006678_1.jpg
# 015516_0.jpg 010244_1.jpg
# 001236_0.jpg 013106_1.jpg
# 015881_0.jpg 018910_1.jpg
# 005285_0.jpg 005388_1.jpg
# 001776_0.jpg 003591_1.jpg
# 004220_0.jpg 010984_1.jpg
